# %%
# !pip install gym==0.26.2
# Out:
# ...
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      --------------------------- ---------- 524.3/721.7 kB 2.1 MB/s eta 0:00:01
#      ---------------------------------------- 721.7/721.7 kB 2.0 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=829852 sha256=c033d31c23e4606c480b033d57af9d21b814c8f03dcda0bb644cddf9b36e78ec
#   Stored in directory: c:\users\pcpal.lk\appdata\local\pip\cache\wheels\99\89\d3\67d22e26cae0df1175f3872a6153b40c0ee63f84e3ca658315
# Successfully built gym
# ...
#
# ...
